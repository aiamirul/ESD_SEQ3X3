# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt

# Load the YOLOv8 model (you can specify 'yolov8n', 'yolov8s', etc.)
model = YOLO('/run/user/1000/gvfs/sftp:host=192.168.1.3/media/infer/SSDC/computer_vision/production_models/FRANCE/FRV/FRV_AUX_ESD159OBJ_000/weights/best.pt')  # Replace with the model you want to use
model = YOLO('/run/user/1000/gvfs/sftp:host=192.168.1.3/media/infer/SSDC/computer_vision/production_models/FRANCE/FRV/FRV_AUX_ACTIONSEQ_001/weights/best.pt')
# Path to the input image
image_path = "CLEANING_T001FR/subfolder_5/2024082600107_5520_SQ3_T001FR.jpg"

# Perform inference
results = model(image_path)

# Extract the results with bounding boxes, confidence scores, and classes
annotated_image = results[0].plot()  # Annotated image with bounding boxes

# Display the image with matplotlib
plt.imshow(cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Hide axes
plt.show()
# Out:
# image 1/1 /home/amir/project/bitbucket/ESD/CLEANING_T001FR/subfolder_5/2024082600107_5520_SQ3_T001FR.jpg: 320x320 NOT 1.00, FRONT_ENT 0.00, LEFT_ENT 0.00, PRE 0.00, RIGHT_ENT 0.00, 3.7ms
# Speed: 13.0ms preprocess, 3.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 320)
